# %% [markdown]
# <a href="https://colab.research.google.com/github/Saradhii/FirstModel/blob/main/Dota2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load the Dota2 Games Results dataset from Google Drive
data_train = pd.read_csv('/content/drive/MyDrive/colab_test_data/dota2Train.csv', header=None)
data_test = pd.read_csv('/content/drive/MyDrive/colab_test_data/dota2Test.csv', header=None)

# Combine the training and test data
data = pd.concat([data_train, data_test])

# Separate the features and the target variable
input_data = data.iloc[:, 1:].values  # all columns except the first one
labels = data.iloc[:, 0].values  # first column

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(input_data, labels, test_size=0.2, random_state=42)

# Further split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Convert labels to one-hot encoded vectors
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

y_train = tf.keras.utils.to_categorical(y_train, num_classes=len(np.unique(y_train)))
y_val = tf.keras.utils.to_categorical(y_val, num_classes=len(np.unique(y_train)))
y_test = tf.keras.utils.to_categorical(y_test, num_classes=len(np.unique(y_train)))

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_shape=(input_data.shape[1],), activation='relu'),  # Input layer to hidden layer
    tf.keras.layers.Dense(128, activation='relu'),  # Additional hidden layer
    tf.keras.layers.Dense(128, activation='relu'),  # Additional hidden layer
    tf.keras.layers.Dense(128, activation='relu'),  # Additional hidden layer
    tf.keras.layers.Dense(len(np.unique(y_train)), activation='softmax')  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_val, y_val))

# Save the trained model
model.save('my_model')
print("Model has been trained and saved.")

# Load the model
loaded_model = tf.keras.models.load_model('my_model')
print("Model has been loaded.")

# Test the model
test_loss, test_acc = loaded_model.evaluate(x_test, y_test, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/50
# 2059/2059 [==============================] - 5s 2ms/step - loss: 0.6941 - accuracy: 0.5458 - val_loss: 0.6772 - val_accuracy: 0.5655
# Epoch 2/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6716 - accuracy: 0.5865 - val_loss: 0.6974 - val_accuracy: 0.5346
# Epoch 3/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6687 - accuracy: 0.5917 - val_loss: 0.6688 - val_accuracy: 0.5955
# Epoch 4/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6669 - accuracy: 0.5952 - val_loss: 0.6645 - val_accuracy: 0.5955
# Epoch 5/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6666 - accuracy: 0.5949 - val_loss: 0.6751 - val_accuracy: 0.5748
# Epoch 6/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6656 - accuracy: 0.5959 - val_loss: 0.6734 - val_accuracy: 0.5774
# Epoch 7/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6657 - accuracy: 0.5953 - val_loss: 0.6645 - val_accuracy: 0.5921
# Epoch 8/50
# 2059/2059 [==============================] - 5s 2ms/step - loss: 0.6652 - accuracy: 0.5960 - val_loss: 0.6659 - val_accuracy: 0.5909
# Epoch 9/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6647 - accuracy: 0.5969 - val_loss: 0.6640 - val_accuracy: 0.5935
# Epoch 10/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6645 - accuracy: 0.5959 - val_loss: 0.6644 - val_accuracy: 0.5921
# Epoch 11/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6641 - accuracy: 0.5989 - val_loss: 0.6660 - val_accuracy: 0.5914
# Epoch 12/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6641 - accuracy: 0.5991 - val_loss: 0.6638 - val_accuracy: 0.5939
# Epoch 13/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6638 - accuracy: 0.5998 - val_loss: 0.6643 - val_accuracy: 0.5955
# Epoch 14/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6640 - accuracy: 0.5965 - val_loss: 0.6640 - val_accuracy: 0.5912
# Epoch 15/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6638 - accuracy: 0.5974 - val_loss: 0.6659 - val_accuracy: 0.5921
# Epoch 16/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6635 - accuracy: 0.5981 - val_loss: 0.6663 - val_accuracy: 0.5936
# Epoch 17/50
# 2059/2059 [==============================] - 5s 2ms/step - loss: 0.6631 - accuracy: 0.5979 - val_loss: 0.6655 - val_accuracy: 0.5916
# Epoch 18/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6631 - accuracy: 0.5994 - val_loss: 0.6645 - val_accuracy: 0.5923
# Epoch 19/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6628 - accuracy: 0.6006 - val_loss: 0.6660 - val_accuracy: 0.5923
# Epoch 20/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6627 - accuracy: 0.6004 - val_loss: 0.6646 - val_accuracy: 0.5926
# Epoch 21/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6622 - accuracy: 0.6003 - val_loss: 0.6649 - val_accuracy: 0.5941
# Epoch 22/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6625 - accuracy: 0.5997 - val_loss: 0.6667 - val_accuracy: 0.5894
# Epoch 23/50
# 2059/2059 [==============================] - 5s 2ms/step - loss: 0.6623 - accuracy: 0.6016 - val_loss: 0.6650 - val_accuracy: 0.5945
# Epoch 24/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6619 - accuracy: 0.6005 - val_loss: 0.6654 - val_accuracy: 0.5919
# Epoch 25/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6617 - accuracy: 0.6006 - val_loss: 0.6651 - val_accuracy: 0.5928
# Epoch 26/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6615 - accuracy: 0.6015 - val_loss: 0.6685 - val_accuracy: 0.5927
# Epoch 27/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6612 - accuracy: 0.6020 - val_loss: 0.6647 - val_accuracy: 0.5924
# Epoch 28/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6611 - accuracy: 0.6009 - val_loss: 0.6650 - val_accuracy: 0.5924
# Epoch 29/50
# 2059/2059 [==============================] - 5s 2ms/step - loss: 0.6601 - accuracy: 0.6024 - val_loss: 0.6687 - val_accuracy: 0.5868
# Epoch 30/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6604 - accuracy: 0.6021 - val_loss: 0.6655 - val_accuracy: 0.5919
# Epoch 31/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6600 - accuracy: 0.6025 - val_loss: 0.6655 - val_accuracy: 0.5927
# Epoch 32/50
# 2059/2059 [==============================] - 5s 2ms/step - loss: 0.6598 - accuracy: 0.6035 - val_loss: 0.6671 - val_accuracy: 0.5912
# Epoch 33/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6592 - accuracy: 0.6031 - val_loss: 0.6753 - val_accuracy: 0.5885
# Epoch 34/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6591 - accuracy: 0.6040 - val_loss: 0.6680 - val_accuracy: 0.5917
# Epoch 35/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6582 - accuracy: 0.6040 - val_loss: 0.6697 - val_accuracy: 0.5919
# Epoch 36/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6580 - accuracy: 0.6049 - val_loss: 0.6701 - val_accuracy: 0.5903
# Epoch 37/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6576 - accuracy: 0.6045 - val_loss: 0.6668 - val_accuracy: 0.5912
# Epoch 38/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6568 - accuracy: 0.6067 - val_loss: 0.6788 - val_accuracy: 0.5864
# Epoch 39/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6567 - accuracy: 0.6049 - val_loss: 0.6734 - val_accuracy: 0.5915
# Epoch 40/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6558 - accuracy: 0.6076 - val_loss: 0.6703 - val_accuracy: 0.5881
# Epoch 41/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6556 - accuracy: 0.6065 - val_loss: 0.6676 - val_accuracy: 0.5836
# Epoch 42/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6554 - accuracy: 0.6068 - val_loss: 0.6707 - val_accuracy: 0.5866
# Epoch 43/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6549 - accuracy: 0.6081 - val_loss: 0.6680 - val_accuracy: 0.5870
# Epoch 44/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6542 - accuracy: 0.6094 - val_loss: 0.6733 - val_accuracy: 0.5899
# Epoch 45/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6535 - accuracy: 0.6101 - val_loss: 0.6737 - val_accuracy: 0.5910
# Epoch 46/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6535 - accuracy: 0.6092 - val_loss: 0.6708 - val_accuracy: 0.5863
# Epoch 47/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6531 - accuracy: 0.6098 - val_loss: 0.6724 - val_accuracy: 0.5859
# Epoch 48/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6524 - accuracy: 0.6111 - val_loss: 0.6721 - val_accuracy: 0.5859
# Epoch 49/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6515 - accuracy: 0.6116 - val_loss: 0.6730 - val_accuracy: 0.5844
# Epoch 50/50
# 2059/2059 [==============================] - 4s 2ms/step - loss: 0.6509 - accuracy: 0.6118 - val_loss: 0.6738 - val_accuracy: 0.5844
# Model has been trained and saved.
# Model has been loaded.
# 644/644 - 1s - loss: 0.6692 - accuracy: 0.5931 - 760ms/epoch - 1ms/step
# Test accuracy: 0.5930836796760559
